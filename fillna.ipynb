# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("bank-loan.csv")

# %%
dataset.head(4)
# Out:
#    age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0   41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1   27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2   40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3   41   1      15       14     120      2.9   2.658720  0.821280      0.0

# %%
dataset.shape
# Out:
# (850, 9)

# %%
dataset.isnull().sum()
# Out:
# age           0
# ed            0
# employ        0
# address       0
# income        0
# debtinc       0
# creddebt      0
# othdebt       0
# default     150
# dtype: int64

# %%
# sns.heatmap(dataset.isnull())

# %%
dataset.drop(columns =["default"],inplace = True)
# /// mising value ko drop karne ke liye pura colum hi hata diya

# %%
dataset.dropna(inplace =True)
# ye pure data me se missing value hata deta hai

# %%
#              handling missing values
 #              (imputing category data)

# %%
# dataset.fillna(10) 
# is me jitna missing value me 10 but kar raha hai

# %%
dataset.fillna(method = "bfill")
# ye ka kar raha hai ki jo piche wale value ko aage wala pe fill kar raha jo khali hai
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_18568\925489389.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method = "bfill")
#      age  ed  employ  address  income  debtinc   creddebt   othdebt
# 0     41   3      17       12     176      9.3  11.359392  5.008608
# 1     27   1      10        6      31     17.3   1.362202  4.000798
# 2     40   1      15       14      55      5.5   0.856075  2.168925
# 3     41   1      15       14     120      2.9   2.658720  0.821280
# 4     24   2       2        0      28     17.3   1.787436  3.056564
# ..   ...  ..     ...      ...     ...      ...        ...       ...
# 845   34   1      12       15      32      2.7   0.239328  0.624672
# 846   32   2      12       11     116      5.7   4.026708  2.585292
# 847   48   1      13       11      38     10.8   0.722304  3.381696
# ...

# %%
#                         scikit- learn

# %%
  dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       850 non-null    int64
#  1   ed        850 non-null    int64
#  2   employ    850 non-null    int64
#  3   address   850 non-null    int64
#  4   income    850 non-null    int64
#  5   debtinc   850 non-null    float64
#  6   creddebt  850 non-null    float64
#  7   othdebt   850 non-null    float64
# dtypes: float64(3), int64(5)
# memory usage: 53.3 KB

# %%
dataset.select_dtypes(include = "float64").columns
# Out:
# Index(['debtinc', 'creddebt', 'othdebt'], dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy = "mean")

# %%
arr = si.fit_transform(dataset[['debtinc', 'creddebt', 'othdebt', 'default']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 arr = si.fit_transform(dataset[['debtinc', 'creddebt', 'othdebt', 'default']])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
pd.DataFrame(arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 pd.DataFrame(arr)
#
# NameError: name 'arr' is not defined

# %%
# ye sklearn ye kiya hai ki jo jaha jaha missing value tha waha waha iska mean value put kar diya hai
